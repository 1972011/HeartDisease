# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart_2022_no_nans.csv')

# %%
df.shape
# Out:
# (246022, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246022 entries, 0 to 246021
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      246022 non-null  object
#  1   Sex                        246022 non-null  object
#  2   GeneralHealth              246022 non-null  object
#  3   PhysicalHealthDays         246022 non-null  float64
#  4   MentalHealthDays           246022 non-null  float64
#  5   LastCheckupTime            246022 non-null  object
#  6   PhysicalActivities         246022 non-null  object
#  7   SleepHours                 246022 non-null  float64
#  8   RemovedTeeth               246022 non-null  object
#  9   HadHeartAttack             246022 non-null  object
#  10  HadAngina                  246022 non-null  object
#  11  HadStroke                  246022 non-null  object
#  12  HadAsthma                  246022 non-null  object
#  13  HadSkinCancer              246022 non-null  object
#  14  HadCOPD                    246022 non-null  object
#  15  HadDepressiveDisorder      246022 non-null  object
#  16  HadKidneyDisease           246022 non-null  object
#  17  HadArthritis               246022 non-null  object
#  18  HadDiabetes                246022 non-null  object
#  19  DeafOrHardOfHearing        246022 non-null  object
#  20  BlindOrVisionDifficulty    246022 non-null  object
#  21  DifficultyConcentrating    246022 non-null  object
#  22  DifficultyWalking          246022 non-null  object
#  23  DifficultyDressingBathing  246022 non-null  object
#  24  DifficultyErrands          246022 non-null  object
#  25  SmokerStatus               246022 non-null  object
#  26  ECigaretteUsage            246022 non-null  object
#  27  ChestScan                  246022 non-null  object
#  28  RaceEthnicityCategory      246022 non-null  object
#  29  AgeCategory                246022 non-null  object
#  30  HeightInMeters             246022 non-null  float64
#  31  WeightInKilograms          246022 non-null  float64
#  32  BMI                        246022 non-null  float64
#  33  AlcoholDrinkers            246022 non-null  object
#  34  HIVTesting                 246022 non-null  object
#  35  FluVaxLast12               246022 non-null  object
#  36  PneumoVaxEver              246022 non-null  object
#  37  TetanusLast10Tdap          246022 non-null  object
#  38  HighRiskLastYear           246022 non-null  object
#  39  CovidPos                   246022 non-null  object
# dtypes: float64(6), object(34)
# memory usage: 75.1+ MB

# %%
df.head(15)
# Out:
#     GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 0               3                 4.0               0.0                3
# 1               3                 0.0               0.0                3
# 2               3                 0.0               0.0                3
# 3               1                 5.0               0.0                3
# 4               2                 3.0              15.0                3
# 5               2                 0.0               0.0                3
# 6               2                 3.0               0.0                3
# 7               1                 5.0               0.0                3
# 8               2                 2.0               0.0                0
# 9               3                 0.0               0.0                3
# 10              3                 0.0               0.0                3
# 11              2                 3.0               4.0                3
# 12              2                 5.0               0.0                3
# 13              2                 0.0               0.0                3
# 14              1                25.0              25.0                3
#
#     PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  HadAngina  \
# 0                    1         9.0             3               0          0
# 1                    1         6.0             3               0          0
# 2                    0         8.0             1               0          0
# 3                    1         9.0             3               0          0
# 4                    1         5.0             2               0          0
# 5                    1         7.0             3               0          0
# 6                    1         8.0             1               0          0
# 7                    1         8.0             2               1          1
# 8                    0         6.0             3               0          0
# 9                    1         7.0             3               0          0
# 10                   1         8.0             2               0          0
# 11                   1         5.0             3               0          0
# 12                   1         5.0             1               1          0
# 13                   0         6.0             2               0          0
# 14                   0         6.0             1               0          1
#
#     HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  AlcoholDrinkers  \
# 0           0  ...            1.60              71.67  27.99                0
# 1           0  ...            1.78              95.25  30.13                0
# 2           0  ...            1.85             108.86  31.66                1
# 3           0  ...            1.70              90.72  31.32                0
# 4           0  ...            1.55              79.38  33.07                0
# 5           0  ...            1.85             120.20  34.96                1
# 6           1  ...            1.63              88.00  33.30                0
# 7           0  ...            1.75              74.84  24.37                0
# 8           0  ...            1.70              78.02  26.94                0
# 9           0  ...            1.68              63.50  22.60                0
# 10          0  ...            1.83             122.47  36.62                1
# 11          0  ...            1.52             108.86  46.87                0
# 12          0  ...            1.88             115.67  32.74                0
# 13          0  ...            1.52              81.65  35.15                0
# 14          0  ...            1.78              86.18  27.26                0
#
#     HIVTesting  FluVaxLast12  PneumoVaxEver  TetanusLast10Tdap  \
# 0            0             1              1                  3
# 1            0             1              1                  2
# 2            0             0              1                  0
# 3            0             1              1                  0
# 4            0             1              1                  0
# 5            1             1              0                  2
# 6            0             1              1                  0
# 7            1             1              1                  0
# 8            0             0              0                  0
# 9            0             1              1                  0
# 10           0             1              1                  3
# 11           0             0              0                  1
# 12           0             1              1                  2
# 13           0             0              0                  3
# 14           0             1              0                  0
#
#     HighRiskLastYear  CovidPos
# 0                  0         2
# 1                  0         2
# 2                  0         0
# 3                  0         0
# 4                  0         2
# 5                  0         2
# 6                  0         2
# 7                  0         0
# 8                  0         0
# 9                  0         2
# 10                 0         2
# 11                 0         0
# 12                 0         2
# 13                 0         2
# 14                 0         0
#
# [15 rows x 38 columns]

# %%
df.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays     SleepHours  HeightInMeters  \
# count       246022.000000     246022.000000  246022.000000   246022.000000
# mean             4.119026          4.167140       7.021331        1.705150
# std              8.405844          8.102687       1.440681        0.106654
# min              0.000000          0.000000       1.000000        0.910000
# 25%              0.000000          0.000000       6.000000        1.630000
# 50%              0.000000          0.000000       7.000000        1.700000
# 75%              3.000000          4.000000       8.000000        1.780000
# max             30.000000         30.000000      24.000000        2.410000
#
#        WeightInKilograms            BMI
# count      246022.000000  246022.000000
# mean           83.615179      28.668136
# std            21.323156       6.513973
# min            28.120000      12.020000
# 25%            68.040000      24.270000
# 50%            81.650000      27.460000
# 75%            95.250000      31.890000
# max           292.570000      97.650000

# %%
df['HeightInMeters'].plot.box()
# Out:
# <Axes: >

# %%
height_column = df[df['HeightInMeters'] == 0.91]
print(height_column)
# Out:
#         GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 13386               0                30.0               0.0                3
# 23185               1                 3.0               2.0                3
# 36257               2                 7.0               0.0                3
# 58093               4                 0.0               2.0                3
# 66346               0                 0.0              30.0                3
# 137738              1                 0.0               5.0                3
#
#         PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 13386                    0         8.0             0               1
# 23185                    1         8.0             2               0
# 36257                    0         8.0             2               0
# 58093                    1         8.0             3               0
# 66346                    0         6.0             0               1
# 137738                   0         8.0             2               0
#
#         HadAngina  HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  \
# 13386           0          0  ...            0.91              56.70  67.81
# 23185           0          0  ...            0.91              81.65  97.65
# 36257           0          0  ...            0.91              54.43  65.10
# 58093           0          0  ...            0.91              40.82  48.82
# 66346           1          0  ...            0.91              68.04  81.37
# 137738          0          0  ...            0.91              61.23  73.24
#
#         AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 13386                 0           1             0              1
# 23185                 1           1             1              0
# 36257                 0           0             0              0
# 58093                 1           0             1              0
# 66346                 0           0             1              1
# 137738                0           0             1              0
#
#         TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 13386                   2                 0         1
# 23185                   2                 0         0
# 36257                   3                 0         2
# 58093                   3                 0         2
# 66346                   0                 0         0
# 137738                  3                 0         2
#
# [6 rows x 38 columns]

# %%
height_column = df[df['HeightInMeters'] == 2.41]
print(height_column)
# Out:
#         GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 121635              1                 0.0              10.0                3
# 196046              2                 0.0               0.0                3
#
#         PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 121635                   1         8.0             3               1
# 196046                   1         6.0             3               0
#
#         HadAngina  HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  \
# 121635          1          1  ...            2.41             116.12  19.94
# 196046          0          0  ...            2.41              90.72  15.58
#
#         AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 121635                1           0             1              1
# 196046                1           0             0              0
#
#         TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 121635                  0                 0         0
# 196046                  2                 0         2
#
# [2 rows x 38 columns]

# %%
df['WeightInKilograms'].plot.box()
# Out:
# <Axes: >

# %%
weight_column = df[df['WeightInKilograms'] == 28.12]
print(weight_column)
# Out:
#         GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 179326              3                 0.0               0.0                0
#
#         PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 179326                   0         8.0             3               0
#
#         HadAngina  HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  \
# 179326          0          0  ...            1.52              28.12  12.11
#
#         AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 179326                0           0             0              0
#
#         TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 179326                  0                 0         2
#
# [1 rows x 38 columns]

# %%
weight_column = df[df['WeightInKilograms'] == 292.57]
print(weight_column)
# Out:
#       GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 9060              1                15.0              15.0                3
#
#       PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  HadAngina  \
# 9060                   0         8.0             3               0          0
#
#       HadStroke  ...  HeightInMeters  WeightInKilograms   BMI  \
# 9060          0  ...            1.85             292.57  85.1
#
#       AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 9060                0           0             0              0
#
#       TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 9060                  3                 0         2
#
# [1 rows x 38 columns]

# %%
df['BMI'].plot.box()
# Out:
# <Axes: >

# %%
bmi_column = df[df['BMI'] == 12.02]
print(bmi_column)
# Out:
#         GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 158296              3                 0.0               0.0                3
#
#         PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 158296                   1         7.0             3               0
#
#         HadAngina  HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  \
# 158296          0          0  ...            1.63              31.75  12.02
#
#         AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 158296                0           0             1              1
#
#         TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 158296                  0                 0         2
#
# [1 rows x 38 columns]

# %%
bmi_column = df[df['BMI'] == 97.65]
print(bmi_column)
# Out:
#         GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 23185               1                 3.0               2.0                3
# 40238               3                 0.0               0.0                3
# 132435              1                21.0               0.0                3
#
#         PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 23185                    1         8.0             2               0
# 40238                    1         8.0             3               0
# 132435                   1         6.0             2               0
#
#         HadAngina  HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  \
# 23185           0          0  ...            0.91              81.65  97.65
# 40238           0          0  ...            1.52             226.80  97.65
# 132435          1          1  ...            1.52             226.80  97.65
#
#         AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 23185                 1           1             1              0
# 40238                 0           0             1              1
# 132435                0           0             1              0
#
#         TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 23185                   2                 0         0
# 40238                   2                 0         0
# 132435                  0                 0         2
#
# [3 rows x 38 columns]

# %%
df.isnull().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# RaceEthnicityCategory        0
# AgeCategory                  0
# HeightInMeters               0
# WeightInKilograms            0
# BMI                          0
# AlcoholDrinkers              0
# HIVTesting                   0
# FluVaxLast12                 0
# PneumoVaxEver                0
# TetanusLast10Tdap            0
# HighRiskLastYear             0
# CovidPos                     0
# dtype: int64

# %%
df.groupby('CovidPos').size()
# Out:
# CovidPos
# No                                                               167306
# Tested positive using home test without a health professional      8392
# Yes                                                               70324
# dtype: int64

# %%
df = df.drop(columns=['State','Sex'])

# %%
binary = {'Yes' : 1, 'No' : 0}

df['PhysicalActivities'] = df['PhysicalActivities'].replace(binary)
df['HadHeartAttack'] = df['HadHeartAttack'].replace(binary)
df['HadAngina'] = df['HadAngina'].replace(binary)
df['HadStroke'] = df['HadStroke'].replace(binary)
df['HadAsthma'] = df['HadAsthma'].replace(binary)
df['HadSkinCancer'] = df['HadSkinCancer'].replace(binary)
df['HadCOPD'] = df['HadCOPD'].replace(binary)
df['HadDepressiveDisorder'] = df['HadDepressiveDisorder'].replace(binary)
df['HadKidneyDisease'] = df['HadKidneyDisease'].replace(binary)
df['HadArthritis'] = df['HadArthritis'].replace(binary)
df['DeafOrHardOfHearing'] = df['DeafOrHardOfHearing'].replace(binary)
df['BlindOrVisionDifficulty'] = df['BlindOrVisionDifficulty'].replace(binary)
df['DifficultyConcentrating'] = df['DifficultyConcentrating'].replace(binary)
df['DifficultyWalking'] = df['DifficultyWalking'].replace(binary)
df['DifficultyDressingBathing'] = df['DifficultyDressingBathing'].replace(binary)
df['DifficultyErrands'] = df['DifficultyErrands'].replace(binary)
df['ChestScan'] = df['ChestScan'].replace(binary)
df['AlcoholDrinkers'] = df['AlcoholDrinkers'].replace(binary)
df['HIVTesting'] = df['HIVTesting'].replace(binary)
df['FluVaxLast12'] = df['FluVaxLast12'].replace(binary)
df['PneumoVaxEver'] = df['PneumoVaxEver'].replace(binary)
df['HighRiskLastYear'] = df['HighRiskLastYear'].replace(binary)
# Out:
# D:\TEMP\ipykernel_5540\3195215391.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['PhysicalActivities'] = df['PhysicalActivities'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadHeartAttack'] = df['HadHeartAttack'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadAngina'] = df['HadAngina'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadStroke'] = df['HadStroke'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadAsthma'] = df['HadAsthma'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadSkinCancer'] = df['HadSkinCancer'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadCOPD'] = df['HadCOPD'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadDepressiveDisorder'] = df['HadDepressiveDisorder'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadKidneyDisease'] = df['HadKidneyDisease'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadArthritis'] = df['HadArthritis'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['DeafOrHardOfHearing'] = df['DeafOrHardOfHearing'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['BlindOrVisionDifficulty'] = df['BlindOrVisionDifficulty'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:15: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['DifficultyConcentrating'] = df['DifficultyConcentrating'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['DifficultyWalking'] = df['DifficultyWalking'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['DifficultyDressingBathing'] = df['DifficultyDressingBathing'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:18: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['DifficultyErrands'] = df['DifficultyErrands'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ChestScan'] = df['ChestScan'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['AlcoholDrinkers'] = df['AlcoholDrinkers'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HIVTesting'] = df['HIVTesting'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['FluVaxLast12'] = df['FluVaxLast12'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:23: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['PneumoVaxEver'] = df['PneumoVaxEver'].replace(binary)
# D:\TEMP\ipykernel_5540\3195215391.py:24: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HighRiskLastYear'] = df['HighRiskLastYear'].replace(binary)

# %%
df.head()
# Out:
#   GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0     Very good                 4.0               0.0
# 1     Very good                 0.0               0.0
# 2     Very good                 0.0               0.0
# 3          Fair                 5.0               0.0
# 4          Good                 3.0              15.0
#
#                                      LastCheckupTime  PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                   1
# 1  Within past year (anytime less than 12 months ...                   1
# 2  Within past year (anytime less than 12 months ...                   0
# 3  Within past year (anytime less than 12 months ...                   1
# 4  Within past year (anytime less than 12 months ...                   1
#
#    SleepHours            RemovedTeeth  HadHeartAttack  HadAngina  HadStroke  \
# 0         9.0            None of them               0          0          0
# 1         6.0            None of them               0          0          0
# 2         8.0  6 or more, but not all               0          0          0
# 3         9.0            None of them               0          0          0
# 4         5.0                  1 to 5               0          0          0
#
#    ...  HeightInMeters  WeightInKilograms    BMI  AlcoholDrinkers  HIVTesting  \
# 0  ...            1.60              71.67  27.99                0           0
# 1  ...            1.78              95.25  30.13                0           0
# 2  ...            1.85             108.86  31.66                1           0
# 3  ...            1.70              90.72  31.32                0           0
# 4  ...            1.55              79.38  33.07                0           0
#
#    FluVaxLast12 PneumoVaxEver  \
# 0             1             1
# 1             1             1
# 2             0             1
# 3             1             1
# 4             1             1
#
#                                    TetanusLast10Tdap  HighRiskLastYear  \
# 0                                 Yes, received Tdap                 0
# 1  Yes, received tetanus shot but not sure what type                 0
# 2  No, did not receive any tetanus shot in the pa...                 0
# 3  No, did not receive any tetanus shot in the pa...                 0
# 4  No, did not receive any tetanus shot in the pa...                 0
#
#    CovidPos
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#
# [5 rows x 38 columns]

# %%
mappingGen = {'Excellent' : 4, 'Very good' : 3, 'Good' : 2, 'Fair' : 1, 'Poor' : 0}
df['GeneralHealth'] = df['GeneralHealth'].replace(mappingGen)

mappingLast = {'Within past year (anytime less than 12 months ago)' : 3, 'Within past 2 years (1 year but less than 2 years ago)' : 2, 'Within past 5 years (2 years but less than 5 years ago)' : 1, '5 or more years ago' : 0}
df['LastCheckupTime'] = df['LastCheckupTime'].replace(mappingLast)

mappingRemoved = {'None of them' : 3, '1 to 5' : 2, '6 or more, but not all' : 1, 'All' : 0}
df['RemovedTeeth'] = df['RemovedTeeth'].replace(mappingRemoved)

mappingDiabet = {'No' : 3, 'No, pre-diabetes or borderline diabetes' : 2, 'Yes, but only during pregnancy (female)' : 1, 'Yes' : 0}
df['HadDiabetes'] = df['HadDiabetes'].replace(mappingDiabet)

mappingSmoker = {'Never smoked' : 3, 'Former smoker' : 2, 'Current smoker - now smokes some days' : 1, 'Current smoker - now smokes every day' : 0}
df['SmokerStatus'] = df['SmokerStatus'].replace(mappingSmoker)

mappingECigar = {'Never used e-cigarettes in my entire life' : 3, 'Not at all (right now)' : 2, 'Use them some days' : 1, 'Use them every day' : 0}
df['ECigaretteUsage'] = df['ECigaretteUsage'].replace(mappingECigar)

mappingRace = {'Black only, Non-Hispanic' : 4, 'Hispanic' : 3, 'Multiracial, Non-Hispanic' : 2, 'Other race only, Non-Hispanic' : 1, 'White only, Non-Hispanic' : 0}
df['RaceEthnicityCategory'] = df['RaceEthnicityCategory'].replace(mappingRace)

mappingAge = {'Age 80 or older' : 12, 'Age 75 to 79' : 11, 'Age 70 to 74' : 10, 'Age 65 to 69' : 9, 'Age 60 to 64' : 8, 'Age 55 to 59' : 7, 'Age 50 to 54' : 6, 'Age 45 to 49' : 5, 'Age 40 to 44' : 4, 'Age 35 to 39' : 3, 'Age 30 to 34' : 2, 'Age 25 to 29' : 1, 'Age 18 to 24' : 0}
df['AgeCategory'] = df['AgeCategory'].replace(mappingAge)

mappingTdap = {'Yes, received Tdap' : 3, 'Yes, received tetanus shot but not sure what type' : 2, 'Yes, received tetanus shot, but not Tdap' : 1, 'No, did not receive any tetanus shot in the past 10 years' : 0}
df['TetanusLast10Tdap'] = df['TetanusLast10Tdap'].replace(mappingTdap)

mappingCov = {'No' : 2, 'Tested positive using home test without a health professional' : 1, 'Yes' : 0}
df['CovidPos'] = df['CovidPos'].replace(mappingCov)
# Out:
# D:\TEMP\ipykernel_5540\3720697363.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['GeneralHealth'] = df['GeneralHealth'].replace(mappingGen)
# D:\TEMP\ipykernel_5540\3720697363.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['LastCheckupTime'] = df['LastCheckupTime'].replace(mappingLast)
# D:\TEMP\ipykernel_5540\3720697363.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['RemovedTeeth'] = df['RemovedTeeth'].replace(mappingRemoved)
# D:\TEMP\ipykernel_5540\3720697363.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['HadDiabetes'] = df['HadDiabetes'].replace(mappingDiabet)
# D:\TEMP\ipykernel_5540\3720697363.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['SmokerStatus'] = df['SmokerStatus'].replace(mappingSmoker)
# D:\TEMP\ipykernel_5540\3720697363.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ECigaretteUsage'] = df['ECigaretteUsage'].replace(mappingECigar)
# D:\TEMP\ipykernel_5540\3720697363.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['RaceEthnicityCategory'] = df['RaceEthnicityCategory'].replace(mappingRace)
# D:\TEMP\ipykernel_5540\3720697363.py:23: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['AgeCategory'] = df['AgeCategory'].replace(mappingAge)
# D:\TEMP\ipykernel_5540\3720697363.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['TetanusLast10Tdap'] = df['TetanusLast10Tdap'].replace(mappingTdap)
# D:\TEMP\ipykernel_5540\3720697363.py:29: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['CovidPos'] = df['CovidPos'].replace(mappingCov)

# %%
df
# Out:
#         GeneralHealth  PhysicalHealthDays  MentalHealthDays  LastCheckupTime  \
# 0                   3                 4.0               0.0                3
# 1                   3                 0.0               0.0                3
# 2                   3                 0.0               0.0                3
# 3                   1                 5.0               0.0                3
# 4                   2                 3.0              15.0                3
# ...               ...                 ...               ...              ...
# 246017              3                 0.0               0.0                2
# 246018              1                 0.0               7.0                3
# 246019              2                 0.0              15.0                3
# 246020              4                 2.0               2.0                3
# 246021              3                 0.0               0.0                3
#
#         PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 0                        1         9.0             3               0
# 1                        1         6.0             3               0
# 2                        0         8.0             1               0
# 3                        1         9.0             3               0
# 4                        1         5.0             2               0
# ...                    ...         ...           ...             ...
# 246017                   1         6.0             3               0
# 246018                   1         7.0             3               0
# 246019                   1         7.0             2               0
# 246020                   1         7.0             3               0
# 246021                   0         5.0             3               1
#
#         HadAngina  HadStroke  ...  HeightInMeters  WeightInKilograms    BMI  \
# 0               0          0  ...            1.60              71.67  27.99
# 1               0          0  ...            1.78              95.25  30.13
# 2               0          0  ...            1.85             108.86  31.66
# 3               0          0  ...            1.70              90.72  31.32
# 4               0          0  ...            1.55              79.38  33.07
# ...           ...        ...  ...             ...                ...    ...
# 246017          0          0  ...            1.78             102.06  32.28
# 246018          0          0  ...            1.93              90.72  24.34
# 246019          0          1  ...            1.68              83.91  29.86
# 246020          0          0  ...            1.70              83.01  28.66
# 246021          0          0  ...            1.83             108.86  32.55
#
#         AlcoholDrinkers  HIVTesting  FluVaxLast12  PneumoVaxEver  \
# 0                     0           0             1              1
# 1                     0           0             1              1
# 2                     1           0             0              1
# 3                     0           0             1              1
# 4                     0           0             1              1
# ...                 ...         ...           ...            ...
# 246017                1           0             0              0
# 246018                0           0             0              0
# 246019                1           1             1              1
# 246020                0           1             1              0
# 246021                0           1             1              1
#
#         TetanusLast10Tdap  HighRiskLastYear  CovidPos
# 0                       3                 0         2
# 1                       2                 0         2
# 2                       0                 0         0
# 3                       0                 0         0
# 4                       0                 0         2
# ...                   ...               ...       ...
# 246017                  2                 0         2
# 246018                  0                 0         0
# 246019                  2                 0         0
# 246020                  2                 0         2
# 246021                  0                 0         0
#
# [246022 rows x 38 columns]

# %%
df.plot.scatter('BMI','WeightInKilograms')
# Out:
# <Axes: xlabel='BMI', ylabel='WeightInKilograms'>
